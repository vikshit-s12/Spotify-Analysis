# %% [markdown]
# pandas operations

# %%
import pandas as pd

# %%
df=pd.read_csv("spotify-top-50-world.csv")

# %%
print(df)
# Out:
#              date  position                                            song  \
# 0      2023-05-18         1                                 Ella Baila Sola
# 1      2023-05-18         2                                       un x100to
# 2      2023-05-18         3                                 La Bebe - Remix
# 3      2023-05-18         4                               Cupid - Twin Ver.
# 4      2023-05-18         5                                         Flowers
# ...           ...       ...                                             ...
# 27795  2024-11-27        46  One Of The Girls (with JENNIE, Lily Rose Depp)
# 27796  2024-11-27        47                            Just the Way You Are
# 27797  2024-11-27        48                                NIGHTS LIKE THIS
# 27798  2024-11-27        49                                          Yellow
# 27799  2024-11-27        50                                Jingle Bell Rock
#
# ...

# %%
display(df)
# Out:
#              date  position                                            song  \
# 0      2023-05-18         1                                 Ella Baila Sola
# 1      2023-05-18         2                                       un x100to
# 2      2023-05-18         3                                 La Bebe - Remix
# 3      2023-05-18         4                               Cupid - Twin Ver.
# 4      2023-05-18         5                                         Flowers
# ...           ...       ...                                             ...
# 27795  2024-11-27        46  One Of The Girls (with JENNIE, Lily Rose Depp)
# 27796  2024-11-27        47                            Just the Way You Are
# 27797  2024-11-27        48                                NIGHTS LIKE THIS
# 27798  2024-11-27        49                                          Yellow
# 27799  2024-11-27        50                                Jingle Bell Rock
#
# ...

# %%
df.head()
# Out:
#          date  position               song                      artist  \
# 0  2023-05-18         1    Ella Baila Sola              Eslabon Armado
# 1  2023-05-18         2          un x100to  Grupo Frontera & Bad Bunny
# 2  2023-05-18         3    La Bebe - Remix      Yng Lvcas & Peso Pluma
# 3  2023-05-18         4  Cupid - Twin Ver.                 FIFTY FIFTY
# 4  2023-05-18         5            Flowers                 Miley Cyrus
#
#    popularity  duration_ms album_type  total_tracks release_date  is_explicit  \
# 0          89       165671      album            16   2023-04-28        False
# 1          99       194563     single             1   2023-04-17        False
# 2          99       234352     single             2   2023-03-17         True
# 3          97       174253     single             3   2023-02-24        False
# 4          91       200600      album            13   2023-03-10        False
#
#                                      album_cover_url
# ...

# %%
df.tail()
# Out:
#              date  position                                            song  \
# 27795  2024-11-27        46  One Of The Girls (with JENNIE, Lily Rose Depp)
# 27796  2024-11-27        47                            Just the Way You Are
# 27797  2024-11-27        48                                NIGHTS LIKE THIS
# 27798  2024-11-27        49                                          Yellow
# 27799  2024-11-27        50                                Jingle Bell Rock
#
#                                      artist  popularity  duration_ms  \
# 27795  The Weeknd & JENNIE & Lily-Rose Depp          89       244684
# 27796                            Bruno Mars          81       220734
# 27797                         The Kid LAROI          88        86983
# 27798                              Coldplay          89       266773
# 27799                           Bobby Helms          82       130973
#
#       album_type  total_tracks release_date  is_explicit  \
# ...

# %%
print(df.dtypes)
# Out:
# date               object
# position            int64
# song               object
# artist             object
# popularity          int64
# duration_ms         int64
# album_type         object
# total_tracks        int64
# release_date       object
# is_explicit          bool
# album_cover_url    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# date               0
# position           0
# song               0
# artist             0
# popularity         0
# duration_ms        0
# album_type         0
# total_tracks       0
# release_date       0
# is_explicit        0
# album_cover_url    0
# dtype: int64
